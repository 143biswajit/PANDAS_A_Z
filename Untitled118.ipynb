# %% [markdown]
# <a href="https://colab.research.google.com/github/143biswajit/PANDAS_A_Z/blob/main/Untitled118.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_iris

# %%
from sklearn import datasets
import pandas as pd

# load iris dataset
iris = datasets.load_iris()
# Since this is a bunch, create a dataframe
iris_df=pd.DataFrame(iris.data)
iris_df['class']=iris.target

iris_df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']
iris_df.dropna(how="all", inplace=True) # remove any empty lines

#selecting only first 4 columns as they are the independent(X) variable
# any kind of feature selection or correlation analysis should be first done on these
iris_X=iris_df.iloc[:,[0,1,2,3]]

# %%
iris_df.head()
# Out:
#    sepal_len  sepal_wid  petal_len  petal_wid  class
# 0        5.1        3.5        1.4        0.2      0
# 1        4.9        3.0        1.4        0.2      0
# 2        4.7        3.2        1.3        0.2      0
# 3        4.6        3.1        1.5        0.2      0
# 4        5.0        3.6        1.4        0.2      0

# %%
import seaborn as sns
# !pip install pivottablejs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pivottablejs import pivot_ui
pivot_ui(iris_df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#independent feature and dependent features
X=dff.iloc[:,:-1]
y=dff.Outcome

# %%
X,y
# Out:
# (     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  0              6      148             72             35        0  33.6
#  1              1       85             66             29        0  26.6
#  2              8      183             64              0        0  23.3
#  3              1       89             66             23       94  28.1
#  4              0      137             40             35      168  43.1
#  ..           ...      ...            ...            ...      ...   ...
#  763           10      101             76             48      180  32.9
#  764            2      122             70             27        0  36.8
#  765            5      121             72             23      112  26.2
#  766            1      126             60              0        0  30.1
#  767            1       93             70             31        0  30.4
#
#       DiabetesPedigreeFunction  Age
#  0                       0.627   50
# ...

# %%
### train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 464           10      115             98              0        0  24.0
# 223            7      142             60             33      190  28.8
# 393            4      116             72             12       87  22.1
# 766            1      126             60              0        0  30.1
# 570            3       78             70              0        0  32.5
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35      140  28.6
# 106            1       96            122              0        0  22.4
# 270           10      101             86             37        0  45.6
# 435            0      141              0              0        0  42.4
# 102            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age
# 464                     1.022   34
# 223                     0.687   61
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
## Postpruning
treemodel=DecisionTreeClassifier()
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.6084607712765957, 0.9615384615384616, 'x[1] <= 154.5\ngini = 0.457\nsamples = 514\nvalue = [332, 182]'),
#  Text(0.32064494680851063, 0.8846153846153846, 'x[7] <= 30.5\ngini = 0.382\nsamples = 432\nvalue = [321, 111]'),
#  Text(0.17952127659574468, 0.8076923076923077, 'x[1] <= 127.5\ngini = 0.24\nsamples = 251\nvalue = [216, 35]'),
#  Text(0.1196808510638298, 0.7307692307692307, 'x[5] <= 45.45\ngini = 0.153\nsamples = 203\nvalue = [186, 17]'),
#  Text(0.10904255319148937, 0.6538461538461539, 'x[0] <= 6.5\ngini = 0.13\nsamples = 200\nvalue = [186, 14]'),
#  Text(0.09840425531914894, 0.5769230769230769, 'x[1] <= 104.5\ngini = 0.122\nsamples = 199\nvalue = [186, 13]'),
#  Text(0.0425531914893617, 0.5, 'x[4] <= 156.0\ngini = 0.037\nsamples = 107\nvalue = [105, 2]'),
#  Text(0.02127659574468085, 0.4230769230769231, 'x[3] <= 41.0\ngini = 0.019\nsamples = 104\nvalue = [103, 1]'),
#  Text(0.010638297872340425, 0.34615384615384615, 'gini = 0.0\nsamples = 97\nvalue = [97, 0]'),
# ...
